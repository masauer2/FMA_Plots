# %%
from FMAPlots.corr import Corr

N_MODES_PER_FILE = 30
MODE_START = 7
MODE_END = 9

# %%
data = Corr.import_dataset("/scratch/masauer2/FRESEANCOARSE/scripts", "template_HIV_amber14sb", "04-FRESEAN/evec_freq1_mode1-30_cg.xyz", 370, N_MODES_PER_FILE)
modes = Corr.get_modes_from_dataset(data, MODE_START, MODE_END)
fig1, ax1 = Corr.plot_correlation_from_modes(modes, "HIV1-Pr")
# Out:
# /home/masauer2/.local/lib/python3.11/site-packages/FMAPlots/corr.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.98])

# %%
data = Corr.import_dataset("/scratch/masauer2/FRESEANCOARSE/scripts", "template_HEWL_amber99sb", "04-FRESEAN/evec_freq1_mode1-30_cg.xyz", 246, N_MODES_PER_FILE)
modes = Corr.get_modes_from_dataset(data, MODE_START, MODE_END)
fig2, ax2 = Corr.plot_correlation_from_modes(modes, "HEWL")
# Out:
# /home/masauer2/.local/lib/python3.11/site-packages/FMAPlots/corr.py:57: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.98])
